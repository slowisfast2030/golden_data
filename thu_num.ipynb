# %%
import json
import jieba
import re
import numpy as np
import pandas as pd
from zhconv import convert


cv_columns = ['cv_id', 'currentPosition', 'desiredPosition', 'industry', 'desiredIndustry', 'majorName', 'skills', 'eduTracks', 'jobTracks', 'projectTracks']
jd_columns = ['jd_id', 'title', 'category_name', 'tags', 'description', 'requirement']


def load_csv_data(data_path):
    '''
    读取csv文件
    '''
    df = pd.read_csv(data_path)
    return df

def col_merge_fun(series, col_list):
    '''
    合并多个文本列
    '''
    merge = ''
    for col in col_list:
        merge = merge + series[col] + ' '
    return merge.strip(' ')

def col_jieba_fun(series, col_name):
    '''
    将文本字符串切词成列表
    '''
    text = series[col_name]
    
    # 切词，精确模式
    col_list = jieba.lcut(text, cut_all=False)
    return col_list

def col_jieba_filter_fun(series, col_name_jieba):
    '''
    对切词后的列表进行过滤
    '''
    col_list_filter = []
    
    # 得到切词后的文本列表
    col_list = series[col_name_jieba]

    pun_masks_english = [",", ".", "/", "[", "]", "{", "}", "(", ")", ":", "*", "#", "!", " ", "\"", "\\"]
    pun_masks_chinese = ["，", "。", "、", "（", "）", "：", "！", "”", "“"]
    pun_masks = pun_masks_english + pun_masks_chinese

    # 过滤
    for tag in col_list:
        # 转中文简体
        tag = convert(tag, "zh-hans")
        # 转英文小写
        tag = tag.lower()

        # 过滤数字
        if tag.isdigit():
            continue
        
        # 过滤单个字符
        if len(tag) <= 1:
            continue
        
        # 过滤标点
        flag = 1
        for pun in pun_masks:
            if pun in tag:
                flag = 0
                break
        if flag == 1:
            col_list_filter.append(tag)
    return col_list_filter

def get_text_jieba_filter(data_path):
    '''
    给定csv数据路径，分别将cv和jd的文本列合并、分词、过滤
    '''
    all_data = load_csv_data(data_path).iloc[:100]

    # 空值填充
    for col in cv_columns[1:]:
        all_data[col].fillna('', inplace=True)
    for col in jd_columns[1:]:
        all_data[col].fillna('', inplace=True)

    cv_jd = ['cv', 'jd']
    cv_jd_columns = [cv_columns, jd_columns]

    col_jieba_filter_list = []
    for col, col_columns in zip(cv_jd, cv_jd_columns):
        col_text = col + '_text'
        col_text_jieba = col_text + '_jieba'
        col_text_jieba_filter = col_text_jieba + '_filter'
        col_jieba_filter_list.append(col_text_jieba_filter)
        
        all_data[col_text] = all_data.apply(col_merge_fun, axis=1, args=(col_columns[1:], ))
        all_data[col_text_jieba] = all_data.apply(col_jieba_fun, axis=1, args=(col_text, ))
        all_data[col_text_jieba_filter] = all_data.apply(col_jieba_filter_fun, axis=1, args=(col_text_jieba, ))

    all_data["equal_words"] = all_data.apply(get_equal_word_num, axis=1, args=(col_jieba_filter_list, ))
    return all_data

def get_equal_word_num(series, col_list):
    cv_text_jieba_filter = series[col_list[0]]
    jd_text_jieba_filter = series[col_list[1]]
    # 这里不能去重吧？！
    # 如何计算这里的重复词的数目呢？
    # 有一个隐患：这里应该找到关键词！！！
    res = set(cv_text_jieba_filter).intersection(set(jd_text_jieba_filter))
    return res


if __name__ == "__main__":
    print("running...")

    data_path = '../data/all_sample_20220821_spark.csv'
    all_data = get_text_jieba_filter(data_path)


    print("all is well!")
# Out:
# running...
# /var/folders/99/wft1658s2mv39cv4wj_rcpqh0000gp/T/ipykernel_15382/3784557050.py:17: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_path)
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/99/wft1658s2mv39cv4wj_rcpqh0000gp/T/jieba.cache
# Loading model cost 0.642 seconds.
# Prefix dict has been built successfully.
# all is well!

# %%
all_data[['cv_text_jieba_filter', 'jd_text_jieba_filter', 'equal_words']]['equal_words'][70]
# Out:
# {'业务',
#  '了解',
#  '事件',
#  '以上',
#  '价值',
#  '传播',
#  '健康',
#  '公司',
#  '具有',
#  '内容',
#  '创意',
#  '制定',
#  '合作',
#  '品牌',
#  '品牌形象',
#  '增长',
#  '媒体',
#  '寻找',
#  '寻求',
#  '市场',
#  '建立',
#  '情况',
#  '提供',
#  '提升',
#  '搭建',
#  '文化',
#  '方案',
#  '核心',
#  '沟通',
#  '活动',
#  '相关',
#  '经理',
#  '结合',
#  '能力',
#  '营销',
#  '行业',
#  '观点',
#  '输出',
#  '运营'}

# %%
all_data.iloc[70]
# Out:
# Unnamed: 0                                                             70
# cv_id                                    2c9207157ef7ed7f017f05f66a8e48e4
# jd_id                                    2c9207157ef7ed16017f017cdcb66b5b
# jd_code                                            JD20220216153952233395
# title                                                              品牌营销经理
#                                               ...
# cv_text_jieba_filter    [品牌, 营销中心, 负责人, 品牌, 营销, 经理, 水利水电, 工程, ai, h5, ...
# jd_text                 品牌营销经理 运营 ["品牌策略","营销","品牌形象","资源整合","品牌营销"] 1...
# jd_text_jieba           [品牌, 营销, 经理,  , 运营,  , [, ", 品牌策略, ", ,, ", 营销...
# jd_text_jieba_filter    [品牌, 营销, 经理, 运营, 品牌策略, 营销, 品牌形象, 资源整合, 品牌, 营销,...
# equal_words             {具有, 核心, 业务, 搭建, 行业, 价值, 传播, 合作, 了解, 品牌形象, 沟通,...
# Name: 70, Length: 94, dtype: object

# %%
all_data
# Out:
#     Unnamed: 0                             cv_id  \
# 0            0  2c9207157bf91042017c0d2beef00470
# 1            1  2c9207157bf91042017c0d979cbb047d
# 2            2  2c9207157bf91042017c7232fbab3be1
# 3            3  2c9207157d308592017d4a94cb1113a1
# 4            4  2c9207157dabb0a3017dbca16cdf4c26
# ..         ...                               ...
# 95          95  2c9207157f8e60cd017fb496c1c865ec
# 96          96  2c9207157f8e60cd017fb496c1c865ec
# 97          97  2c9207157f8e60cd017fb54103920147
# 98          98  2c9207157f8e60cd017fb63683d90200
# 99          99  2c9207157f8e60cd017fb6cef29a1a65
#
#                                jd_id                 jd_code  \
# 0   2c9207157bcbb76b017bcde2b46d04cd  JD20210910115615503390
# 1   2c9207157bcbb76b017bf7f2bbbb3153  JD20210918160449291911
# 2   2c9207157bf94d99017c108f769405e0  JD20210923104433723714
# 3   2c9207157d2f0ec5017d5a9265ba33d9  JD20211126124504034196
# 4   2c9207157d631abb017d6eed1c79139f  JD20211130113932574529
# ..                               ...                     ...
# 95  2c9207157f347800017f8c86a6aa1c27  JD20220315154149035139
# 96  2c92071580b3a1010180bb1f744358ed  JD20220513095402415013
# 97  2c9207157f93e289017fb4d51f7b21b9  JD20220302120215391989
# 98  2c9207157d2f0ec5017d50bb40e96081  JD20211124145628163562
# 99  2c9207157f93e289017fb642aac84bfe  JD20220323181136758264
#
#                  title               deadline category_id category_name  \
# 0              市场营销负责人  2021-11-30 23:59:59.0      140101          市场营销
# 1               会员管理经理  2021-10-31 23:59:59.0      130101          用户运营
# 2               产品市场经理  2021-10-31 23:59:59.0      110101          产品经理
# 3        海外区域运营经理/高级经理  2022-02-28 23:59:59.0      130000            运营
# 4               高级项目经理                    NaN      310000          高级管理
# ..                 ...                    ...         ...           ...
# 95  高级/资深平台产品运营（云游戏方向）                    NaN      130102          产品运营
# 96              品牌营销专家                    NaN      130000            运营
# 97              品牌创意总监                    NaN      140203          品牌公关
# 98             功能安全工程师                    NaN      100000            技术
# 99             采购专员/主管                    NaN      250100            采购
#
#                           company_id     company_name  ...  \
# 0   2c9207157bcbb76b017bcdd5f254038a   深圳市快易典教育科技有限公司  ...
# 1   2c9207157b9b9199017bc895b2f23a39     上海晨光文具股份有限公司  ...
# 2   2c9207157bf94d99017c108765c804aa  凯斯纽荷兰（中国）管理有限公司  ...
# 3   2c9207157bf94d99017c1714f34e1715   广州市百果园网络科技有限公司  ...
# 4   2c9207157bf94d99017c2f902e952262       深圳纳欣科技有限公司  ...
# ..                               ...              ...  ...
# 95  2c9207157e9b9f12017ed72c5d0b6587   广州网易-游戏平台&技术中心  ...
# 96  2c9207157d95bfde017d9e38116d44e3           阿里灵犀互娱  ...
# 97  2c9207157f347800017f43d5ead6201c       小米科技有限责任公司  ...
# 98  2c9207157d162406017d2c01e3dc0831     比亚迪半导体股份有限公司  ...
# 99  2c9207157d95bfde017d98acfd0411ae   重庆博腾制药科技股份有限公司  ...
#
#                                             jobTracks  \
# 0   ['{"companyName": "深圳市亿科数字科技有限公司", "descriptio...
# 1   ['{"companyName": "北京美餐好客科技有限公司", "companyNatu...
# 2   ['{"companyName": "Continental Tires (China) L...
# 3   ['{"companyName": "北京星制科技有限公司（全民快乐）", "descrip...
# 4   ['{"companyName": "酷狗音乐", "companyTags": "互联网+...
# ..                                                ...
# 95  ['{"companyName": "好游快爆项目组", "description": "•...
# 96  ['{"companyName": "好游快爆项目组", "description": "•...
# 97  ['{"companyName": "滴滴", "description": "工作内容: ...
# 98  ['{"companyName": "山东产业技术研究院", "description": ...
# 99  ['{"companyName": "江西邦泰绿色生态产业园发展有限公司", "descri...
#
#                                         projectTracks      ds.1  \
# 0   ['{"companyName": "*深圳市蜂联科技有限公司（奇虎360）", "desc...  20220821
# 1   ['{"description": "项目描述: 母婴类人群，包含童装、童鞋、奶粉。\\n运...  20220821
# 2                                                      20220821
# 3   ['{"description": "主播表现，直播平均 2 场，平台新用户 12926，主...  20220821
# 4   ['{"companyName": "酷狗音乐", "description": "酷狗20...  20220821
# ..                                                ...       ...
# 95  ['{"description": "曾于线上手游周边同人社团“SS project”中任职...  20220821
# 96  ['{"description": "曾于线上手游周边同人社团“SS project”中任职...  20220821
# 97  ['{"companyName": "李奥贝纳（4a）", "description": "...  20220821
# 98  ['{"description": "项目经理\\n2018/12-2020/02\\n内容...  20220821
# 99                                                     20220821
#
#                                               cv_text  \
# 0   副总裁/副总经理    国际经济与贸易 ["Ipd","App","Kpi","Crm","...
# 1   数字化营销经理  餐饮业  电气工程及其自动化 ["H5","C1","Seo","Sem"...
# 2   Marketing ["Based","Control","Sap Crm","Improv...
# 3   泰国国家经理    企业管理 ["App","Resume","运营","策划","营销",...
# 4   项目经理 项目经理/主管 互联网+ 智能硬件,互联网+ 英语 ["智能硬件"] ['{"de...
# ..                                                ...
# 95  二次元游戏模块运营负责人 平台运营/游戏运营   工商管理 ["App","Https","...
# 96  二次元游戏模块运营负责人 平台运营/游戏运营   工商管理 ["App","Https","...
# 97  创意专家    视觉传达 ["Group","Resume","营销","功能","策划",...
# 98  上海证券交易所技术总监    通信与信息系统 ["Ui","App","Erp","Saas...
# 99  采购主管 销售/采购经理   应用化学 ["API","弱电","运营","装修","沟通能...
#
#                                         cv_text_jieba  \
# 0   [副总裁, /, 副总经理,  ,  ,  ,  , 国际, 经济, 与, 贸易,  , [...
# 1   [数字化, 营销, 经理,  ,  , 餐饮业,  ,  , 电气工程, 及其, 自动化, ...
# 2   [Marketing,  , [, ", Based, ", ,, ", Control, ...
# 3   [泰国, 国家, 经理,  ,  ,  ,  , 企业, 管理,  , [, ", App,...
# 4   [项目经理,  , 项目经理, /, 主管,  , 互联网, +,  , 智能, 硬件, ,...
# ..                                                ...
# 95  [二次元, 游戏, 模块, 运营, 负责人,  , 平台, 运营, /, 游戏, 运营,  ...
# 96  [二次元, 游戏, 模块, 运营, 负责人,  , 平台, 运营, /, 游戏, 运营,  ...
# 97  [创意, 专家,  ,  ,  ,  , 视觉, 传达,  , [, ", Group, "...
# 98  [上海证券交易所, 技术, 总监,  ,  ,  ,  , 通信, 与, 信息系统,  , ...
# 99  [采购, 主管,  , 销售, /, 采购, 经理,  ,  ,  , 应用化学,  , [...
#
#                                  cv_text_jieba_filter  \
# 0   [副总裁, 副总经理, 国际, 经济, 贸易, ipd, app, kpi, crm, vi...
# 1   [数字化, 营销, 经理, 餐饮业, 电气工程, 及其, 自动化, h5, c1, seo,...
# 2   [marketing, based, control, sap, crm, improve,...
# 3   [泰国, 国家, 经理, 企业, 管理, app, resume, 运营, 策划, 营销, ...
# 4   [项目经理, 项目经理, 主管, 互联网, 智能, 硬件, 互联网, 英语, 智能, 硬件,...
# ..                                                ...
# 95  [二次元, 游戏, 模块, 运营, 负责人, 平台, 运营, 游戏, 运营, 工商管理, a...
# 96  [二次元, 游戏, 模块, 运营, 负责人, 平台, 运营, 游戏, 运营, 工商管理, a...
# 97  [创意, 专家, 视觉, 传达, group, resume, 营销, 功能, 策划, 街舞...
# 98  [上海证券交易所, 技术, 总监, 通信, 信息系统, ui, app, erp, saas...
# 99  [采购, 主管, 销售, 采购, 经理, 应用化学, api, 弱电, 运营, 装修, 沟通...
#
#                                               jd_text  \
# 0   市场营销负责人 市场营销 ["营销","管理","销售","战略规划","管理工作"] 1、...
# 1   会员管理经理 用户运营 ["会员运营","会员管理","管理","营销","社群运营"] 1...
# 2   产品市场经理 产品经理 ["EXCEL","OFFICE","PPT","UI"] 1、•S...
# 3   海外区域运营经理/高级经理 运营 ["管理","运营","团队管理","电商","游戏"] ...
# 4   高级项目经理 高级管理 ["项目管理","推广","归档","风险评估","交货"] 1、负...
# ..                                                ...
# 95  高级/资深平台产品运营（云游戏方向） 产品运营 ["游戏","运营","平台运营","策划"...
# 96  品牌营销专家 运营 ["品牌运营","游戏","品牌营销","营销","BI"] 1、负责互...
# 97  品牌创意总监 品牌公关 ["管理","沟通能力","销售","营销","品牌推广"] 1、是...
# 98  功能安全工程师 技术 ["芯片功能安全","测试","审核","项目管理","架构"] 1、...
# 99  采购专员/主管 采购 ["采购","管理","采购计划","审核","化工"] 1.\t寻找...
#
#                                         jd_text_jieba  \
# 0   [市场营销, 负责人,  , 市场营销,  , [, ", 营销, ", ,, ", 管理,...
# 1   [会员, 管理, 经理,  , 用户, 运营,  , [, ", 会员, 运营, ", ,,...
# 2   [产品, 市场, 经理,  , 产品, 经理,  , [, ", EXCEL, ", ,, ...
# 3   [海外, 区域, 运营, 经理, /, 高级, 经理,  , 运营,  , [, ", 管理...
# 4   [高级, 项目经理,  , 高级, 管理,  , [, ", 项目管理, ", ,, ", ...
# ..                                                ...
# 95  [高级, /, 资深, 平台, 产品, 运营, （, 云, 游戏, 方向, ）,  , 产品...
# 96  [品牌, 营销, 专家,  , 运营,  , [, ", 品牌, 运营, ", ,, ", ...
# 97  [品牌, 创意, 总监,  , 品牌, 公关,  , [, ", 管理, ", ,, ", ...
# 98  [功能, 安全, 工程师,  , 技术,  , [, ", 芯片, 功能, 安全, ", ,...
# 99  [采购, 专员, /, 主管,  , 采购,  , [, ", 采购, ", ,, ", 管...
#
#                                  jd_text_jieba_filter  \
# 0   [市场营销, 负责人, 市场营销, 营销, 管理, 销售, 战略规划, 管理工作, 岗位职责...
# 1   [会员, 管理, 经理, 用户, 运营, 会员, 运营, 会员, 管理, 管理, 营销, 社...
# 2   [产品, 市场, 经理, 产品, 经理, excel, office, ppt, ui, s...
# 3   [海外, 区域, 运营, 经理, 高级, 经理, 运营, 管理, 运营, 团队, 管理, 电...
# 4   [高级, 项目经理, 高级, 管理, 项目管理, 推广, 归档, 风险, 评估, 交货, 负...
# ..                                                ...
# 95  [高级, 资深, 平台, 产品, 运营, 游戏, 方向, 产品, 运营, 游戏, 运营, 平...
# 96  [品牌, 营销, 专家, 运营, 品牌, 运营, 游戏, 品牌, 营销, 营销, bi, 负...
# 97  [品牌, 创意, 总监, 品牌, 公关, 管理, 沟通, 能力, 销售, 营销, 品牌, 推...
# 98  [功能, 安全, 工程师, 技术, 芯片, 功能, 安全, 测试, 审核, 项目管理, 架构...
# 99  [采购, 专员, 主管, 采购, 采购, 管理, 采购计划, 审核, 化工, 寻找, 符合,...
#
#                                           equal_words
# 0   {开拓, 方面, 目标, 至少, 达成, 负责人, 行业, 负责, 协调, 管理, 优秀, ...
# 1   {目标, 零售, 行业, 负责, 数据分析, 管理, 权益, 优化, 合作, 玩法, 追踪,...
# 2   {intelligence, team, business, with, manage, r...
# 3   {本科, 营收, 负责, 数据分析, 管理, 方向, 运营, 国家, 相关, 执行, 直播,...
# 4   {本科, 目标, 成员, 负责, 协调, 管理, 交付, 优化, 良好, 归档, 实现, 产...
# ..                                                ...
# 95  {游戏, 行业, 负责, 协调, 跟进, 促进, 针对, 产出, 运营, 相关, cp, 用...
# 96  {游戏, 行业, 负责, 玩家, 案例, 合作, 了解, 长期, 一定, 营销, 运营, 重...
# 97  {具有, 本科, 传播, 领域, 沟通, 产品, 营销, 深入, 品牌, 创意, 执行, 团...
# 98  {系统, 客户, 技术, 流程, 需求, 掌握, 机构, 研发, 应用, 工作, 架构, 制...
# 99  {定期, 比价, 符合, 开发, 审核, 询价, 筛选, 管理, 分析, 设备, 五金, 专...
#
# [100 rows x 94 columns]

# %%
a = [1,2,3]
b = [2,3,4]
c = set(a).intersection(set(b))
len(c)
# Out:
# 2

# %%
import re
import json
import numpy as np
import pandas as pd
import jieba
from zhconv import convert
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA

# %%
# 读入20220821所有数据
all_data = pd.read_csv('../data/all_sample_20220821_spark.csv').drop(['Unnamed: 0'], axis=1)
# Out:
# /var/folders/99/wft1658s2mv39cv4wj_rcpqh0000gp/T/ipykernel_5261/3330071591.py:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_data = pd.read_csv('../data/all_sample_20220821_spark.csv').drop(['Unnamed: 0'], axis=1)

# %%
all_data.columns
# Out:
# Index(['cv_id', 'jd_id', 'jd_code', 'title', 'deadline', 'category_id',
#        'category_name', 'company_id', 'company_name', 'recruit_number',
#        'work_age', 'min_annual_salary', 'max_annual_salary',
#        'min_month_salary', 'max_month_salary', 'pay_months', 'created_by_name',
#        'created_by', 'created_at', 'updated_by', 'updated_at', 'tenant_id',
#        'guarantee_period', 'status', 'recommended_rcn', 'tags', 'workplaces',
#        'description', 'school', 'degree', 'post_level_id', 'requirement', 'ds',
#        '_id', 'additionInfo', 'age', 'certificates', 'code', 'competenceScore',
#        'completeness', 'countryCode', 'createdAt', 'createdBy',
#        'currentCompany', 'currentPosition', 'currentSalary', 'dateOfBirth',
#        'degree.1', 'desiredIndustry', 'desiredPosition', 'desiredSalary',
#        'dutyTime', 'expectLocation', 'gender', 'importType', 'industry',
#        'interviewTime', 'jobIntentStatus', 'languageSkills', 'languages',
#        'location', 'maintainerId', 'majorName', 'maritalStatus', 'name',
#        'ownerId', 'resignReason', 'schoolName', 'selfEvaluation', 'skills',
#        'sourceId', 'sourceSite', 'sourceType', 'tenantId', 'uncompletedField',
#        'updatedAt', 'updatedBy', 'updatedTime', 'uploaderId', 'version',
#        'workYear', 'avatar', 'eduTracks', 'jobTracks', 'projectTracks',
#        'ds.1'],
#       dtype='object')

# %% [markdown]
# 黄金数据集数值特征
# * EqualWord cv文本和jd文本中，重合的关键词数目
# * work_duration cv平均每份工作的平均时间
# * salary
#
# 深度模型缺失值的填充！

# %% [markdown]
# ‘CVs’: 包括CV中recommendReason、cvKeyword、jobTracks的三类文本
#
# ‘JDs’: 包括JD中jdKeyword、description、requirement的三类文本
#
# EqualWord: CVs文本和JDs文本中，重合的关键词数目 （表示匹配程度，用于wide）

# %%
# 这里是cv和jd可用的文本类特征了
cv_columns = ['cv_id', 'currentPosition', 'desiredPosition', 'industry', 'desiredIndustry', 'majorName', 'skills', 'eduTracks', 'jobTracks', 'projectTracks']
jd_columns = ['jd_id', 'title', 'category_name', 'tags', 'description', 'requirement']

# %% [markdown]
# 对于上述cv文本字段的一些看法:
# * industry和desiredIndustry的缺失值比较严重
# * majorName感觉字段错位，里面有很多学校信息.建议重新入库。

# %%
cv_data = all_data[cv_columns]
cv_data
# Out:
#                                   cv_id currentPosition       desiredPosition  \
# 0      2c9207157bf91042017c0d2beef00470        副总裁/副总经理                   NaN
# 1      2c9207157bf91042017c0d979cbb047d         数字化营销经理                   NaN
# 2      2c9207157bf91042017c7232fbab3be1             NaN                   NaN
# 3      2c9207157d308592017d4a94cb1113a1          泰国国家经理                   NaN
# 4      2c9207157dabb0a3017dbca16cdf4c26            项目经理               项目经理/主管
# ...                                 ...             ...                   ...
# 81291  8a69d7c28219945301823d8a08d14e70         生产工、包装工  生产制造/机械设计/制造/机械设备工程师
# 81292  8a69d7c282199453018247bac4a36859          高级市场总监         市场/市场/营销/市场营销
# 81293  8a69d7c282199453018247bac4a36859          高级市场总监         市场/市场/营销/市场营销
# 81294  8a69d7db826df6c201827b4338cd60c2            java          技术/后端开发/Java
# 81295  8a69f60582b081f50182b33dea795d4d        零售营销部负责人            运营/运营/电商运营
#
#       industry desiredIndustry  majorName  \
# 0          NaN             NaN    国际经济与贸易
# 1          餐饮业             NaN  电气工程及其自动化
# 2          NaN             NaN  Marketing
# 3          NaN             NaN       企业管理
# 4         互联网+       智能硬件,互联网+         英语
# ...        ...             ...        ...
# 81291      NaN             NaN          无
# 81292      NaN             NaN       上海大学
# 81293      NaN             NaN       上海大学
# 81294      NaN             NaN     太原理工大学
# 81295      NaN             NaN   湖南人文科技学院
#
#                                                   skills  \
# 0      ["Ipd","App","Kpi","Crm","View","优化","策划","营销"...
# 1      ["H5","C1","Seo","Sem","Top","Kpi","Crm","优化",...
# 2      ["Based","Control","Sap Crm","Improve","Indivi...
# 3      ["App","Resume","运营","策划","营销","搭建","笔译","舞蹈",...
# 4                                               ["智能硬件"]
# ...                                                  ...
# 81291                                                 电气
# 81292    搭建,翻译,功能,医学,数据库,Education,产品管理,产品经理,医疗器械,英语听说读写
# 81293    搭建,翻译,功能,医学,数据库,Education,产品管理,产品经理,医疗器械,英语听说读写
# 81294  Bi,Cdn,Elk,Git,Yii,App,Php,Ext,Etl,Java,Sina,H...
# 81295  电商,优化,策划,运营,客服,搭建,营销,数据分析,电子商务,运营管理,管理工作,团队建设,...
#
#                                                eduTracks  \
# 0      ['{"degree": "本科", "endDate": "2008-07", "id":...
# 1      ['{"degree": "本科", "endDate": "2014-06", "id":...
# 2      ['{"degree": "硕士", "endDate": "2012-09", "id":...
# 3      ['{"degree": "硕士", "endDate": "2019-06", "id":...
# 4      ['{"degree": "硕士", "endDate": "2016-07", "id":...
# ...                                                  ...
# 81291  ['{"endDate": "2022-07", "unified": false, "de...
# 81292  ['{"schoolTag": "211", "endDate": "1999-07", "...
# 81293  ['{"schoolTag": "211", "endDate": "1999-07", "...
# 81294  ['{"endDate": "2015-06", "unified": false, "de...
# 81295  ['{"endDate": "2013-01", "unified": true, "deg...
#
#                                                jobTracks  \
# 0      ['{"companyName": "深圳市亿科数字科技有限公司", "descriptio...
# 1      ['{"companyName": "北京美餐好客科技有限公司", "companyNatu...
# 2      ['{"companyName": "Continental Tires (China) L...
# 3      ['{"companyName": "北京星制科技有限公司（全民快乐）", "descrip...
# 4      ['{"companyName": "酷狗音乐", "companyTags": "互联网+...
# ...                                                  ...
# 81291  ['{"endDate": "2022-07", "companyName": "江门市新会...
# 81292  ['{"endDate": "2022-07", "companyName": "上海微创医...
# 81293  ['{"endDate": "2022-07", "companyName": "上海微创医...
# 81294  ['{"endDate": "2020-07", "companyName": "金山云",...
# 81295  ['{"endDate": "2022-08", "companyName": "厦门安踏服...
#
#                                            projectTracks
# 0      ['{"companyName": "*深圳市蜂联科技有限公司（奇虎360）", "desc...
# 1      ['{"description": "项目描述: 母婴类人群，包含童装、童鞋、奶粉。\\n运...
# 2                                                    NaN
# 3      ['{"description": "主播表现，直播平均 2 场，平台新用户 12926，主...
# 4      ['{"companyName": "酷狗音乐", "description": "酷狗20...
# ...                                                  ...
# 81291                                 ['{"name": null}']
# 81292                                 ['{"name": null}']
# 81293                                 ['{"name": null}']
# 81294                                 ['{"name": null}']
# 81295                                 ['{"name": null}']
#
# [81296 rows x 10 columns]

# %%
jd_data = all_data[jd_columns]
jd_data
# Out:
#                                   jd_id            title category_name  \
# 0      2c9207157bcbb76b017bcde2b46d04cd          市场营销负责人          市场营销
# 1      2c9207157bcbb76b017bf7f2bbbb3153           会员管理经理          用户运营
# 2      2c9207157bf94d99017c108f769405e0           产品市场经理          产品经理
# 3      2c9207157d2f0ec5017d5a9265ba33d9    海外区域运营经理/高级经理            运营
# 4      2c9207157d631abb017d6eed1c79139f           高级项目经理          高级管理
# ...                                 ...              ...           ...
# 81291  8a69f6f8823a93b901823d891b761d51             技术经理       机械设备工程师
# 81292  8a69c468826ee9b40182831bedfc5e79           中央市场总监          市场总监
# 81293  8a69f6f8823a93b9018247c30aca4e3d           中央市场总监         市场/营销
# 81294  2c92071580dd3ab70180f18714e119c0  java开发工程师（不限方向）          Java
# 81295  8a69d77e82926b4101829f733f84545b               研发       食品/饮料研发
#
#                                         tags  \
# 0             ["营销","管理","销售","战略规划","管理工作"]
# 1           ["会员运营","会员管理","管理","营销","社群运营"]
# 2              ["EXCEL","OFFICE","PPT","UI"]
# 3               ["管理","运营","团队管理","电商","游戏"]
# 4             ["项目管理","推广","归档","风险评估","交货"]
# ...                                      ...
# 81291          ["材料","考核","维修","技术标准","不锈钢"]
# 81292         ["市场推广","医疗器械","语言","材料","营销"]
# 81293         ["市场推广","医疗器械","语言","材料","营销"]
# 81294  ["java","微服务/性能优化","SQL","架构","需求分析"]
# 81295           ["管理","销售","材料","测试","项目开发"]
#
#                                              description  \
# 0      1、岗位职责:2、主导制定公司营销战略规划并参与公司整体战略规划制定。3、全面管理公司的市场...
# 1      1、岗位职责：2、1. 负责“九木杂物社”品牌全渠道会员体系的管理，规划品牌会员运营方向，包...
# 2      1、•Support regional strategic planning and mar...
# 3      1、负责短视频业务的运营策略制定，配合完成公司的营收业务指标；2、主导团队的业务方向，包括但...
# 4      1、负责从产品建立到第一批生产交付的全过程项目管理;2、 负责实现产品要求、进度、成本、质量...
# ...                                                  ...
# 81291  职责描述：1、全面负责公司技术标准制、各岗位的工艺制定跟改善；2、重要设备参数收集管控包各棍...
# 81292  1. 把握行业市场发展趋势，分析全球市场动态，拟定公司产品市场发展战略规划；2. 结合公司战...
# 81293  1. 把握行业市场发展趋势，分析全球市场动态，拟定公司产品市场发展战略规划；2. 结合公司战...
# 81294  1、负责公司OA产品的功能规划、需求分析设计、技术实现和用户体验；2、负责所属模块的代码开发...
# 81295  1、掌握市场动态和产品趋势，对公司产品改进、提升、创新，开发新产品(速冻包点、速冻水饺、预制...
#
#                                              requirement
# 0                                             1、电商2、线下营销
# 1                                         1、有会员管理、会员活动经验
# 2                                              1、find jd
# 3      1、本科及以上学历优先，3年以上社交、直播、游戏、电商或相关行业运营工作经验；2、英语听说读...
# 4      1、 本科及以上学历，计算机科学或相关专业。能用英语交流者优先;2、5年以上可穿戴相关产品项...
# ...                                                  ...
# 81291  任职要求：1、具备压延400系不锈钢材料技术相关工作经验，能对水扎四六棍扎异常原因分析解决、...
# 81292  1. 本科及以上学历，医学、医疗器械相关专业者优先；2. 10年及以上市场工作经验，5年以上...
# 81293  1. 本科及以上学历，医学、医疗器械相关专业者优先；2. 10年及以上市场工作经验，5年以上...
# 81294  1、本科及以上学历，2年以上的Java开发及应用经验，计算机或者相关专业;2、良好的问题理解...
# 81295  1、大专或大专以上学历，年龄30-50岁，食品、管理类相关专业；2、对市场及行业信息非常敏锐...
#
# [81296 rows x 6 columns]

# %%
# 把下列text字段拼接起来，统一经过分词处理，得到两个list
cv_columns = ['cv_id', 'currentPosition', 'desiredPosition', 'industry', 'desiredIndustry', 'majorName', 'skills', 'eduTracks', 'jobTracks', 'projectTracks']
jd_columns = ['jd_id', 'title', 'category_name', 'tags', 'description', 'requirement']

# %%
type(all_data['desiredIndustry'][10])
# Out:
# float

# %% [markdown]
# ## 先处理cv的文本列

# %%
# step1 对cv的各文本列做空值填充
cv_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81296 entries, 0 to 81295
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cv_id            81296 non-null  object
#  1   currentPosition  78952 non-null  object
#  2   desiredPosition  51408 non-null  object
#  3   industry         15671 non-null  object
#  4   desiredIndustry  9345 non-null   object
#  5   majorName        80395 non-null  object
#  6   skills           74527 non-null  object
#  7   eduTracks        81293 non-null  object
#  8   jobTracks        80324 non-null  object
#  9   projectTracks    55283 non-null  object
# dtypes: object(10)
# memory usage: 6.2+ MB

# %%
for col in cv_columns[1:]:
    #print(col)
    cv_data[col].fillna('', inplace=True)  

cv_data.info()
# Out:
# /var/folders/99/wft1658s2mv39cv4wj_rcpqh0000gp/T/ipykernel_5261/4276026414.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cv_data[col].fillna('', inplace=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81296 entries, 0 to 81295
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cv_id            81296 non-null  object
#  1   currentPosition  81296 non-null  object
#  2   desiredPosition  81296 non-null  object
#  3   industry         81296 non-null  object
#  4   desiredIndustry  81296 non-null  object
#  5   majorName        81296 non-null  object
#  6   skills           81296 non-null  object
#  7   eduTracks        81296 non-null  object
#  8   jobTracks        81296 non-null  object
#  9   projectTracks    81296 non-null  object
# dtypes: object(10)
# memory usage: 6.2+ MB

# %%
# step2 将cv的文本列拼接
def col_merge_fun(series, col_list):
    '''
    合并多个文本列
    '''
    merge = ''
    for col in col_list:
        merge = merge + series[col] + ' '
    return merge.strip(' ')

cv_data['cv_text'] = cv_data.apply(col_merge_fun, axis=1, args=(cv_columns[1:], ))
cv_data
# Out:
# /var/folders/99/wft1658s2mv39cv4wj_rcpqh0000gp/T/ipykernel_5261/206899020.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cv_data['cv_text'] = cv_data.apply(col_merge_fun, axis=1, args=(cv_columns[1:], ))
#                                   cv_id currentPosition       desiredPosition  \
# 0      2c9207157bf91042017c0d2beef00470        副总裁/副总经理
# 1      2c9207157bf91042017c0d979cbb047d         数字化营销经理
# 2      2c9207157bf91042017c7232fbab3be1
# 3      2c9207157d308592017d4a94cb1113a1          泰国国家经理
# 4      2c9207157dabb0a3017dbca16cdf4c26            项目经理               项目经理/主管
# ...                                 ...             ...                   ...
# 81291  8a69d7c28219945301823d8a08d14e70         生产工、包装工  生产制造/机械设计/制造/机械设备工程师
# 81292  8a69d7c282199453018247bac4a36859          高级市场总监         市场/市场/营销/市场营销
# 81293  8a69d7c282199453018247bac4a36859          高级市场总监         市场/市场/营销/市场营销
# 81294  8a69d7db826df6c201827b4338cd60c2            java          技术/后端开发/Java
# 81295  8a69f60582b081f50182b33dea795d4d        零售营销部负责人            运营/运营/电商运营
#
#       industry desiredIndustry  majorName  \
# 0                                 国际经济与贸易
# 1          餐饮业                  电气工程及其自动化
# 2                               Marketing
# 3                                    企业管理
# 4         互联网+       智能硬件,互联网+         英语
# ...        ...             ...        ...
# 81291                                   无
# 81292                                上海大学
# 81293                                上海大学
# 81294                              太原理工大学
# 81295                            湖南人文科技学院
#
#                                                   skills  \
# 0      ["Ipd","App","Kpi","Crm","View","优化","策划","营销"...
# 1      ["H5","C1","Seo","Sem","Top","Kpi","Crm","优化",...
# 2      ["Based","Control","Sap Crm","Improve","Indivi...
# 3      ["App","Resume","运营","策划","营销","搭建","笔译","舞蹈",...
# 4                                               ["智能硬件"]
# ...                                                  ...
# 81291                                                 电气
# 81292    搭建,翻译,功能,医学,数据库,Education,产品管理,产品经理,医疗器械,英语听说读写
# 81293    搭建,翻译,功能,医学,数据库,Education,产品管理,产品经理,医疗器械,英语听说读写
# 81294  Bi,Cdn,Elk,Git,Yii,App,Php,Ext,Etl,Java,Sina,H...
# 81295  电商,优化,策划,运营,客服,搭建,营销,数据分析,电子商务,运营管理,管理工作,团队建设,...
#
#                                                eduTracks  \
# 0      ['{"degree": "本科", "endDate": "2008-07", "id":...
# 1      ['{"degree": "本科", "endDate": "2014-06", "id":...
# 2      ['{"degree": "硕士", "endDate": "2012-09", "id":...
# 3      ['{"degree": "硕士", "endDate": "2019-06", "id":...
# 4      ['{"degree": "硕士", "endDate": "2016-07", "id":...
# ...                                                  ...
# 81291  ['{"endDate": "2022-07", "unified": false, "de...
# 81292  ['{"schoolTag": "211", "endDate": "1999-07", "...
# 81293  ['{"schoolTag": "211", "endDate": "1999-07", "...
# 81294  ['{"endDate": "2015-06", "unified": false, "de...
# 81295  ['{"endDate": "2013-01", "unified": true, "deg...
#
#                                                jobTracks  \
# 0      ['{"companyName": "深圳市亿科数字科技有限公司", "descriptio...
# 1      ['{"companyName": "北京美餐好客科技有限公司", "companyNatu...
# 2      ['{"companyName": "Continental Tires (China) L...
# 3      ['{"companyName": "北京星制科技有限公司（全民快乐）", "descrip...
# 4      ['{"companyName": "酷狗音乐", "companyTags": "互联网+...
# ...                                                  ...
# 81291  ['{"endDate": "2022-07", "companyName": "江门市新会...
# 81292  ['{"endDate": "2022-07", "companyName": "上海微创医...
# 81293  ['{"endDate": "2022-07", "companyName": "上海微创医...
# 81294  ['{"endDate": "2020-07", "companyName": "金山云",...
# 81295  ['{"endDate": "2022-08", "companyName": "厦门安踏服...
#
#                                            projectTracks  \
# 0      ['{"companyName": "*深圳市蜂联科技有限公司（奇虎360）", "desc...
# 1      ['{"description": "项目描述: 母婴类人群，包含童装、童鞋、奶粉。\\n运...
# 2
# 3      ['{"description": "主播表现，直播平均 2 场，平台新用户 12926，主...
# 4      ['{"companyName": "酷狗音乐", "description": "酷狗20...
# ...                                                  ...
# 81291                                 ['{"name": null}']
# 81292                                 ['{"name": null}']
# 81293                                 ['{"name": null}']
# 81294                                 ['{"name": null}']
# 81295                                 ['{"name": null}']
#
#                                                  cv_text
# 0      副总裁/副总经理    国际经济与贸易 ["Ipd","App","Kpi","Crm","...
# 1      数字化营销经理  餐饮业  电气工程及其自动化 ["H5","C1","Seo","Sem"...
# 2      Marketing ["Based","Control","Sap Crm","Improv...
# 3      泰国国家经理    企业管理 ["App","Resume","运营","策划","营销",...
# 4      项目经理 项目经理/主管 互联网+ 智能硬件,互联网+ 英语 ["智能硬件"] ['{"de...
# ...                                                  ...
# 81291  生产工、包装工 生产制造/机械设计/制造/机械设备工程师   无 电气 ['{"endDat...
# 81292  高级市场总监 市场/市场/营销/市场营销   上海大学 搭建,翻译,功能,医学,数据库,Ed...
# 81293  高级市场总监 市场/市场/营销/市场营销   上海大学 搭建,翻译,功能,医学,数据库,Ed...
# 81294  java 技术/后端开发/Java   太原理工大学 Bi,Cdn,Elk,Git,Yii,...
# 81295  零售营销部负责人 运营/运营/电商运营   湖南人文科技学院 电商,优化,策划,运营,客服,...
#
# [81296 rows x 11 columns]

# %%
# step3 对cv_text列进行分词
def col_jieba_fun(series, col_name):
    '''
    将文本字符串切词成列表
    '''
    text = series[col_name]
    
    # 切词，精确模式
    col_list = jieba.lcut(text, cut_all=False)
    return col_list

# 比较耗时
cv_data['cv_text_jieba'] = cv_data.apply(col_jieba_fun, axis=1, args=('cv_text', ))
cv_data
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/99/wft1658s2mv39cv4wj_rcpqh0000gp/T/jieba.cache
# Loading model cost 0.881 seconds.
# Prefix dict has been built successfully.
# /var/folders/99/wft1658s2mv39cv4wj_rcpqh0000gp/T/ipykernel_5261/1766939689.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cv_data['cv_text_jieba'] = cv_data.apply(col_jieba_fun, axis=1, args=('cv_text', ))
#                                   cv_id currentPosition       desiredPosition  \
# 0      2c9207157bf91042017c0d2beef00470        副总裁/副总经理
# 1      2c9207157bf91042017c0d979cbb047d         数字化营销经理
# 2      2c9207157bf91042017c7232fbab3be1
# 3      2c9207157d308592017d4a94cb1113a1          泰国国家经理
# 4      2c9207157dabb0a3017dbca16cdf4c26            项目经理               项目经理/主管
# ...                                 ...             ...                   ...
# 81291  8a69d7c28219945301823d8a08d14e70         生产工、包装工  生产制造/机械设计/制造/机械设备工程师
# 81292  8a69d7c282199453018247bac4a36859          高级市场总监         市场/市场/营销/市场营销
# 81293  8a69d7c282199453018247bac4a36859          高级市场总监         市场/市场/营销/市场营销
# 81294  8a69d7db826df6c201827b4338cd60c2            java          技术/后端开发/Java
# 81295  8a69f60582b081f50182b33dea795d4d        零售营销部负责人            运营/运营/电商运营
#
#       industry desiredIndustry  majorName  \
# 0                                 国际经济与贸易
# 1          餐饮业                  电气工程及其自动化
# 2                               Marketing
# 3                                    企业管理
# 4         互联网+       智能硬件,互联网+         英语
# ...        ...             ...        ...
# 81291                                   无
# 81292                                上海大学
# 81293                                上海大学
# 81294                              太原理工大学
# 81295                            湖南人文科技学院
#
#                                                   skills  \
# 0      ["Ipd","App","Kpi","Crm","View","优化","策划","营销"...
# 1      ["H5","C1","Seo","Sem","Top","Kpi","Crm","优化",...
# 2      ["Based","Control","Sap Crm","Improve","Indivi...
# 3      ["App","Resume","运营","策划","营销","搭建","笔译","舞蹈",...
# 4                                               ["智能硬件"]
# ...                                                  ...
# 81291                                                 电气
# 81292    搭建,翻译,功能,医学,数据库,Education,产品管理,产品经理,医疗器械,英语听说读写
# 81293    搭建,翻译,功能,医学,数据库,Education,产品管理,产品经理,医疗器械,英语听说读写
# 81294  Bi,Cdn,Elk,Git,Yii,App,Php,Ext,Etl,Java,Sina,H...
# 81295  电商,优化,策划,运营,客服,搭建,营销,数据分析,电子商务,运营管理,管理工作,团队建设,...
#
#                                                eduTracks  \
# 0      ['{"degree": "本科", "endDate": "2008-07", "id":...
# 1      ['{"degree": "本科", "endDate": "2014-06", "id":...
# 2      ['{"degree": "硕士", "endDate": "2012-09", "id":...
# 3      ['{"degree": "硕士", "endDate": "2019-06", "id":...
# 4      ['{"degree": "硕士", "endDate": "2016-07", "id":...
# ...                                                  ...
# 81291  ['{"endDate": "2022-07", "unified": false, "de...
# 81292  ['{"schoolTag": "211", "endDate": "1999-07", "...
# 81293  ['{"schoolTag": "211", "endDate": "1999-07", "...
# 81294  ['{"endDate": "2015-06", "unified": false, "de...
# 81295  ['{"endDate": "2013-01", "unified": true, "deg...
#
#                                                jobTracks  \
# 0      ['{"companyName": "深圳市亿科数字科技有限公司", "descriptio...
# 1      ['{"companyName": "北京美餐好客科技有限公司", "companyNatu...
# 2      ['{"companyName": "Continental Tires (China) L...
# 3      ['{"companyName": "北京星制科技有限公司（全民快乐）", "descrip...
# 4      ['{"companyName": "酷狗音乐", "companyTags": "互联网+...
# ...                                                  ...
# 81291  ['{"endDate": "2022-07", "companyName": "江门市新会...
# 81292  ['{"endDate": "2022-07", "companyName": "上海微创医...
# 81293  ['{"endDate": "2022-07", "companyName": "上海微创医...
# 81294  ['{"endDate": "2020-07", "companyName": "金山云",...
# 81295  ['{"endDate": "2022-08", "companyName": "厦门安踏服...
#
#                                            projectTracks  \
# 0      ['{"companyName": "*深圳市蜂联科技有限公司（奇虎360）", "desc...
# 1      ['{"description": "项目描述: 母婴类人群，包含童装、童鞋、奶粉。\\n运...
# 2
# 3      ['{"description": "主播表现，直播平均 2 场，平台新用户 12926，主...
# 4      ['{"companyName": "酷狗音乐", "description": "酷狗20...
# ...                                                  ...
# 81291                                 ['{"name": null}']
# 81292                                 ['{"name": null}']
# 81293                                 ['{"name": null}']
# 81294                                 ['{"name": null}']
# 81295                                 ['{"name": null}']
#
#                                                  cv_text  \
# 0      副总裁/副总经理    国际经济与贸易 ["Ipd","App","Kpi","Crm","...
# 1      数字化营销经理  餐饮业  电气工程及其自动化 ["H5","C1","Seo","Sem"...
# 2      Marketing ["Based","Control","Sap Crm","Improv...
# 3      泰国国家经理    企业管理 ["App","Resume","运营","策划","营销",...
# 4      项目经理 项目经理/主管 互联网+ 智能硬件,互联网+ 英语 ["智能硬件"] ['{"de...
# ...                                                  ...
# 81291  生产工、包装工 生产制造/机械设计/制造/机械设备工程师   无 电气 ['{"endDat...
# 81292  高级市场总监 市场/市场/营销/市场营销   上海大学 搭建,翻译,功能,医学,数据库,Ed...
# 81293  高级市场总监 市场/市场/营销/市场营销   上海大学 搭建,翻译,功能,医学,数据库,Ed...
# 81294  java 技术/后端开发/Java   太原理工大学 Bi,Cdn,Elk,Git,Yii,...
# 81295  零售营销部负责人 运营/运营/电商运营   湖南人文科技学院 电商,优化,策划,运营,客服,...
#
#                                            cv_text_jieba
# 0      [副总裁, /, 副总经理,  ,  ,  ,  , 国际, 经济, 与, 贸易,  , [...
# 1      [数字化, 营销, 经理,  ,  , 餐饮业,  ,  , 电气工程, 及其, 自动化, ...
# 2      [Marketing,  , [, ", Based, ", ,, ", Control, ...
# 3      [泰国, 国家, 经理,  ,  ,  ,  , 企业, 管理,  , [, ", App,...
# 4      [项目经理,  , 项目经理, /, 主管,  , 互联网, +,  , 智能, 硬件, ,...
# ...                                                  ...
# 81291  [生产, 工, 、, 包装工,  , 生产, 制造, /, 机械设计, /, 制造, /, ...
# 81292  [高级, 市场总监,  , 市场, /, 市场, /, 营销, /, 市场营销,  ,  ,...
# 81293  [高级, 市场总监,  , 市场, /, 市场, /, 营销, /, 市场营销,  ,  ,...
# 81294  [java,  , 技术, /, 后, 端, 开发, /, Java,  ,  ,  , 太...
# 81295  [零售, 营销部, 负责人,  , 运营, /, 运营, /, 电商, 运营,  ,  , ...
#
# [81296 rows x 12 columns]

# %%
cv_data['cv_text_jieba']
# Out:
# 0        [副总裁, /, 副总经理,  ,  ,  ,  , 国际, 经济, 与, 贸易,  , [...
# 1        [数字化, 营销, 经理,  ,  , 餐饮业,  ,  , 电气工程, 及其, 自动化, ...
# 2        [Marketing,  , [, ", Based, ", ,, ", Control, ...
# 3        [泰国, 国家, 经理,  ,  ,  ,  , 企业, 管理,  , [, ", App,...
# 4        [项目经理,  , 项目经理, /, 主管,  , 互联网, +,  , 智能, 硬件, ,...
#                                ...
# 81291    [生产, 工, 、, 包装工,  , 生产, 制造, /, 机械设计, /, 制造, /, ...
# 81292    [高级, 市场总监,  , 市场, /, 市场, /, 营销, /, 市场营销,  ,  ,...
# 81293    [高级, 市场总监,  , 市场, /, 市场, /, 营销, /, 市场营销,  ,  ,...
# 81294    [java,  , 技术, /, 后, 端, 开发, /, Java,  ,  ,  , 太...
# 81295    [零售, 营销部, 负责人,  , 运营, /, 运营, /, 电商, 运营,  ,  , ...
# Name: cv_text_jieba, Length: 81296, dtype: object

# %%
# step4 对cv_text_jieba列进行过滤
def col_jieba_filter_fun(series, col_name_jieba):
    '''
    对切词后的列表进行过滤
    '''
    col_list_filter = []
    
    # 得到切词后的文本列表
    col_list = series[col_name_jieba]

    pun_masks_english = [",", ".", "/", "[", "]", "{", "}", "(", ")", ":", "*", "#", "!", " ", "\"", "\\"]
    pun_masks_chinese = ["，", "。", "、", "（", "）", "：", "！", "”", "“"]
    pun_masks = pun_masks_english + pun_masks_chinese

    # 过滤
    for tag in col_list:
        # 转中文简体
        tag = convert(tag, "zh-hans")
        # 转英文小写
        tag = tag.lower()

        # 过滤数字
        if tag.isdigit():
            continue
        
        # 过滤单个字符
        if len(tag) <= 1:
            continue
        
        # 过滤标点
        flag = 1
        for pun in pun_masks:
            if pun in tag:
                flag = 0
                break
        if flag == 1:
            col_list_filter.append(tag)
    return col_list_filter

cv_data['cv_text_jieba_filter'] = cv_data.apply(col_jieba_filter_fun, axis=1, args=('cv_text_jieba', ))
cv_data
# Out:
# /var/folders/99/wft1658s2mv39cv4wj_rcpqh0000gp/T/ipykernel_5261/517688065.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cv_data['cv_text_jieba_filter'] = cv_data.apply(col_jieba_filter_fun, axis=1, args=('cv_text_jieba', ))
#                                   cv_id currentPosition       desiredPosition  \
# 0      2c9207157bf91042017c0d2beef00470        副总裁/副总经理
# 1      2c9207157bf91042017c0d979cbb047d         数字化营销经理
# 2      2c9207157bf91042017c7232fbab3be1
# 3      2c9207157d308592017d4a94cb1113a1          泰国国家经理
# 4      2c9207157dabb0a3017dbca16cdf4c26            项目经理               项目经理/主管
# ...                                 ...             ...                   ...
# 81291  8a69d7c28219945301823d8a08d14e70         生产工、包装工  生产制造/机械设计/制造/机械设备工程师
# 81292  8a69d7c282199453018247bac4a36859          高级市场总监         市场/市场/营销/市场营销
# 81293  8a69d7c282199453018247bac4a36859          高级市场总监         市场/市场/营销/市场营销
# 81294  8a69d7db826df6c201827b4338cd60c2            java          技术/后端开发/Java
# 81295  8a69f60582b081f50182b33dea795d4d        零售营销部负责人            运营/运营/电商运营
#
#       industry desiredIndustry  majorName  \
# 0                                 国际经济与贸易
# 1          餐饮业                  电气工程及其自动化
# 2                               Marketing
# 3                                    企业管理
# 4         互联网+       智能硬件,互联网+         英语
# ...        ...             ...        ...
# 81291                                   无
# 81292                                上海大学
# 81293                                上海大学
# 81294                              太原理工大学
# 81295                            湖南人文科技学院
#
#                                                   skills  \
# 0      ["Ipd","App","Kpi","Crm","View","优化","策划","营销"...
# 1      ["H5","C1","Seo","Sem","Top","Kpi","Crm","优化",...
# 2      ["Based","Control","Sap Crm","Improve","Indivi...
# 3      ["App","Resume","运营","策划","营销","搭建","笔译","舞蹈",...
# 4                                               ["智能硬件"]
# ...                                                  ...
# 81291                                                 电气
# 81292    搭建,翻译,功能,医学,数据库,Education,产品管理,产品经理,医疗器械,英语听说读写
# 81293    搭建,翻译,功能,医学,数据库,Education,产品管理,产品经理,医疗器械,英语听说读写
# 81294  Bi,Cdn,Elk,Git,Yii,App,Php,Ext,Etl,Java,Sina,H...
# 81295  电商,优化,策划,运营,客服,搭建,营销,数据分析,电子商务,运营管理,管理工作,团队建设,...
#
#                                                eduTracks  \
# 0      ['{"degree": "本科", "endDate": "2008-07", "id":...
# 1      ['{"degree": "本科", "endDate": "2014-06", "id":...
# 2      ['{"degree": "硕士", "endDate": "2012-09", "id":...
# 3      ['{"degree": "硕士", "endDate": "2019-06", "id":...
# 4      ['{"degree": "硕士", "endDate": "2016-07", "id":...
# ...                                                  ...
# 81291  ['{"endDate": "2022-07", "unified": false, "de...
# 81292  ['{"schoolTag": "211", "endDate": "1999-07", "...
# 81293  ['{"schoolTag": "211", "endDate": "1999-07", "...
# 81294  ['{"endDate": "2015-06", "unified": false, "de...
# 81295  ['{"endDate": "2013-01", "unified": true, "deg...
#
#                                                jobTracks  \
# 0      ['{"companyName": "深圳市亿科数字科技有限公司", "descriptio...
# 1      ['{"companyName": "北京美餐好客科技有限公司", "companyNatu...
# 2      ['{"companyName": "Continental Tires (China) L...
# 3      ['{"companyName": "北京星制科技有限公司（全民快乐）", "descrip...
# 4      ['{"companyName": "酷狗音乐", "companyTags": "互联网+...
# ...                                                  ...
# 81291  ['{"endDate": "2022-07", "companyName": "江门市新会...
# 81292  ['{"endDate": "2022-07", "companyName": "上海微创医...
# 81293  ['{"endDate": "2022-07", "companyName": "上海微创医...
# 81294  ['{"endDate": "2020-07", "companyName": "金山云",...
# 81295  ['{"endDate": "2022-08", "companyName": "厦门安踏服...
#
#                                            projectTracks  \
# 0      ['{"companyName": "*深圳市蜂联科技有限公司（奇虎360）", "desc...
# 1      ['{"description": "项目描述: 母婴类人群，包含童装、童鞋、奶粉。\\n运...
# 2
# 3      ['{"description": "主播表现，直播平均 2 场，平台新用户 12926，主...
# 4      ['{"companyName": "酷狗音乐", "description": "酷狗20...
# ...                                                  ...
# 81291                                 ['{"name": null}']
# 81292                                 ['{"name": null}']
# 81293                                 ['{"name": null}']
# 81294                                 ['{"name": null}']
# 81295                                 ['{"name": null}']
#
#                                                  cv_text  \
# 0      副总裁/副总经理    国际经济与贸易 ["Ipd","App","Kpi","Crm","...
# 1      数字化营销经理  餐饮业  电气工程及其自动化 ["H5","C1","Seo","Sem"...
# 2      Marketing ["Based","Control","Sap Crm","Improv...
# 3      泰国国家经理    企业管理 ["App","Resume","运营","策划","营销",...
# 4      项目经理 项目经理/主管 互联网+ 智能硬件,互联网+ 英语 ["智能硬件"] ['{"de...
# ...                                                  ...
# 81291  生产工、包装工 生产制造/机械设计/制造/机械设备工程师   无 电气 ['{"endDat...
# 81292  高级市场总监 市场/市场/营销/市场营销   上海大学 搭建,翻译,功能,医学,数据库,Ed...
# 81293  高级市场总监 市场/市场/营销/市场营销   上海大学 搭建,翻译,功能,医学,数据库,Ed...
# 81294  java 技术/后端开发/Java   太原理工大学 Bi,Cdn,Elk,Git,Yii,...
# 81295  零售营销部负责人 运营/运营/电商运营   湖南人文科技学院 电商,优化,策划,运营,客服,...
#
#                                            cv_text_jieba  \
# 0      [副总裁, /, 副总经理,  ,  ,  ,  , 国际, 经济, 与, 贸易,  , [...
# 1      [数字化, 营销, 经理,  ,  , 餐饮业,  ,  , 电气工程, 及其, 自动化, ...
# 2      [Marketing,  , [, ", Based, ", ,, ", Control, ...
# 3      [泰国, 国家, 经理,  ,  ,  ,  , 企业, 管理,  , [, ", App,...
# 4      [项目经理,  , 项目经理, /, 主管,  , 互联网, +,  , 智能, 硬件, ,...
# ...                                                  ...
# 81291  [生产, 工, 、, 包装工,  , 生产, 制造, /, 机械设计, /, 制造, /, ...
# 81292  [高级, 市场总监,  , 市场, /, 市场, /, 营销, /, 市场营销,  ,  ,...
# 81293  [高级, 市场总监,  , 市场, /, 市场, /, 营销, /, 市场营销,  ,  ,...
# 81294  [java,  , 技术, /, 后, 端, 开发, /, Java,  ,  ,  , 太...
# 81295  [零售, 营销部, 负责人,  , 运营, /, 运营, /, 电商, 运营,  ,  , ...
#
#                                     cv_text_jieba_filter
# 0      [副总裁, 副总经理, 国际, 经济, 贸易, ipd, app, kpi, crm, vi...
# 1      [数字化, 营销, 经理, 餐饮业, 电气工程, 及其, 自动化, h5, c1, seo,...
# 2      [marketing, based, control, sap, crm, improve,...
# 3      [泰国, 国家, 经理, 企业, 管理, app, resume, 运营, 策划, 营销, ...
# 4      [项目经理, 项目经理, 主管, 互联网, 智能, 硬件, 互联网, 英语, 智能, 硬件,...
# ...                                                  ...
# 81291  [生产, 包装工, 生产, 制造, 机械设计, 制造, 机械设备, 工程师, 电气, end...
# 81292  [高级, 市场总监, 市场, 市场, 营销, 市场营销, 上海大学, 搭建, 翻译, 功能,...
# 81293  [高级, 市场总监, 市场, 市场, 营销, 市场营销, 上海大学, 搭建, 翻译, 功能,...
# 81294  [java, 技术, 开发, java, 太原, 理工大学, bi, cdn, elk, g...
# 81295  [零售, 营销部, 负责人, 运营, 运营, 电商, 运营, 湖南, 人文, 科技, 学院,...
#
# [81296 rows x 13 columns]

# %%
cv_data['cv_text_jieba_filter'][0]
# Out:
# ['副总裁',
#  '副总经理',
#  '国际',
#  '经济',
#  '贸易',
#  'ipd',
#  'app',
#  'kpi',
#  'crm',
#  'view',
#  '优化',
#  '策划',
#  '营销',
#  '运营',
#  '搭建',
#  '电商',
#  '前端',
#  '架构',
#  '财务',
#  '客服',
#  '迭代',
#  '数据',
#  '营销策划',
#  '需求',
#  '管理',
#  '网络设备',
#  '电子商务',
#  '合同',
#  '管理',
#  '成本',
#  '分析',
#  '运营',
#  '管理',
#  '市场营销',
#  '产品',
#  '管理',
#  '需求',
#  '分析',
#  '经营',
#  '管理',
#  '风险',
#  '控制',
#  '产品开发',
#  '团队',
#  '建设',
#  'degree',
#  '本科',
#  'enddate',
#  'id',
#  '2c9207157dbedf8d017dc28fbc5d336d',
#  'majorname',
#  '国际',
#  '经济',
#  '贸易',
#  'schoolname',
#  '湖南',
#  '科技',
#  '学院',
#  'startdate',
#  'companyname',
#  '深圳市',
#  '亿科',
#  '数字',
#  '科技',
#  '有限公司',
#  'description',
#  '工作',
#  '职责',
#  '公司',
#  '管理',
#  'n1',
#  '确定',
#  '发展',
#  '方向',
#  '结合',
#  '公司',
#  '特点',
#  '竞争',
#  '优势',
#  '行业',
#  '机会',
#  '信息',
#  '确定',
#  '公司',
#  '未来',
#  '主要',
#  '从事',
#  '行业',
#  '赛道',
#  '移动',
#  '互联网',
#  '创意',
#  '为主',
#  '技术',
#  '导向',
#  '三大',
#  '战略',
#  'n2',
#  '企业',
#  '文化',
#  '建设',
#  'ceo',
#  '一道',
#  '深入',
#  '公司',
#  '文化',
#  '进行',
#  '总结',
#  '分析',
#  '通过',
#  '投票',
#  '讨论',
#  '调研',
#  '方式',
#  '最终',
#  '确定',
#  '公司',
#  '文化',
#  '各个',
#  '事业部',
#  '进行',
#  '推行',
#  '落实',
#  'n3',
#  '内部',
#  '流程',
#  '优化',
#  '协同',
#  '销售',
#  '运营',
#  '创意',
#  '财务',
#  '技术',
#  '商务',
#  '部门',
#  '整个',
#  '公司',
#  '内部',
#  '流程',
#  '进行',
#  '梳理',
#  '最终',
#  '落脚',
#  '公司',
#  '信息化',
#  '系统',
#  '建设',
#  '从而',
#  '提升',
#  '公司',
#  '运转',
#  '效率',
#  '规避',
#  '相关',
#  '风险',
#  'n4',
#  '薪酬',
#  '改革',
#  '协助',
#  'ceo',
#  '整个',
#  '公司',
#  '人员',
#  '职级',
#  '薪酬',
#  '考核',
#  '绩效',
#  '进行',
#  '深入',
#  '改革',
#  '建立',
#  '人才',
#  '评价',
#  '体系',
#  '晋升',
#  '体系',
#  '从而',
#  '提升',
#  '员工',
#  '人效',
#  '水平',
#  '改善',
#  '公司',
#  '经营',
#  '指标',
#  'n5',
#  '数据',
#  '系统化',
#  '搭建',
#  '协同',
#  '技术',
#  '部门',
#  '已经',
#  '业务部门',
#  '需求',
#  '重新',
#  '整个',
#  '公司',
#  '消耗',
#  '充值',
#  '回款',
#  '成本',
#  '商务',
#  '政策',
#  '进行',
#  '梳理',
#  '以及',
#  '取数',
#  '来源',
#  '时间',
#  '媒体',
#  '综合',
#  '优化',
#  '评估',
#  '形成',
#  '一套',
#  '更为',
#  '科学',
#  '准确',
#  '核算',
#  '逻辑',
#  '提升',
#  '公司',
#  '管理',
#  '管理决策',
#  '数据',
#  '依据',
#  '以及',
#  '公司',
#  '正规化',
#  '体系化',
#  '建设',
#  'n6',
#  '总经办',
#  '助理',
#  '协助',
#  '董事长',
#  'ceo',
#  '制定',
#  '上述',
#  '相关',
#  '目标',
#  '以及',
#  '关键',
#  '行动',
#  '方案',
#  '协同',
#  '相关',
#  '部门',
#  '落实',
#  '运营',
#  '管理',
#  'n1',
#  '运营',
#  '团队',
#  '根据',
#  '行业',
#  '人效',
#  '产出',
#  '客户',
#  '赛道',
#  '进行',
#  '组织',
#  '架构',
#  '调整',
#  '划分',
#  '确保',
#  '人尽',
#  '其职',
#  '产出',
#  '最大化',
#  'n2',
#  '结合',
#  '技术',
#  '部门',
#  '前沿',
#  '发展',
#  '推动',
#  '运营',
#  '部门',
#  '大力',
#  '使用',
#  '智投',
#  '创意',
#  '畅享',
#  '平台',
#  '比较',
#  '先进',
#  '工作',
#  '从而',
#  '提升',
#  '单个',
#  '运营',
#  '基建',
#  '能力',
#  'n3',
#  '单个',
#  '运营',
#  '团队',
#  '作为',
#  '战斗',
#  '单元',
#  '结合',
#  '客户',
#  '标签',
#  '完善',
#  '公司',
#  '客户',
#  '分配机制',
#  '确保',
#  '单个',
#  '客户',
#  '消耗',
#  '产出',
#  '最大化',
#  'n4',
#  '案列',
#  '分析',
#  '组织',
#  '人员',
#  '优秀',
#  '素材',
#  '数据',
#  '进行',
#  '分析',
#  '提炼',
#  '相关',
#  '案列',
#  '以及',
#  '成功',
#  '关键',
#  '要素',
#  '运营',
#  '内部',
#  '销售',
#  '部门',
#  '进行',
#  '推广',
#  'n5',
#  '运营',
#  '专业化',
#  '信息',
#  '建设',
#  '公司',
#  '整个',
#  '运营',
#  '团队',
#  '通过',
#  '广告投放',
#  '数据',
#  '行业',
#  '数据',
#  '协助',
#  'ceo',
#  '建立',
#  '数据中心',
#  '公司',
#  '在职',
#  '运营',
#  '客户',
#  '行业',
#  '完成',
#  '标签',
#  '分类',
#  '工作',
#  '实现',
#  '运营',
#  '体系化',
#  '数据',
#  '高效化',
#  '投放',
#  '智能化',
#  '客户',
#  '风险管理',
#  'n1',
#  '优化',
#  '销售',
#  '流程',
#  '客户',
#  '引入',
#  '商务',
#  '政策',
#  '授信',
#  '合同',
#  '流程',
#  '摸底',
#  '效率',
#  '风险',
#  '信息化',
#  '建设',
#  '角度',
#  '完善',
#  '该条',
#  '流程',
#  'n2',
#  '客户',
#  '建立',
#  '评估',
#  '机制',
#  '销售',
#  '客户',
#  '引入',
#  '进行',
#  '评估',
#  '制定',
#  '相关',
#  '标准',
#  '确保',
#  '客户',
#  '质量',
#  'n3',
#  '老客户',
#  '进行',
#  '分级管理',
#  '对于',
#  '合作',
#  '客户',
#  '消耗',
#  '回款',
#  '毛利',
#  '经营',
#  '利润',
#  '角度',
#  '进行',
#  '评级',
#  '确保',
#  '公司',
#  '资源',
#  '合理',
#  '使用',
#  'n4',
#  '客户',
#  '管理',
#  '完善',
#  '公司',
#  '客户',
#  '管理',
#  '办法',
#  '针对',
#  '销售',
#  '行为',
#  '进行',
#  '约束',
#  '拜访',
#  '招标',
#  '关系',
#  '深度',
#  '进行',
#  '明确',
#  '推动',
#  '成立',
#  '公司',
#  '客户',
#  '部门',
#  'n5',
#  '客户档案',
#  '信息化',
#  '针对',
#  '客户',
#  '特殊性',
#  '信息化',
#  '作为',
#  '承载',
#  '确保',
#  '客户',
#  '自从',
#  '合作',
#  '以来',
#  '一个',
#  '行为',
#  '一次',
#  '合作',
#  '档案',
#  '可循',
#  'n6',
#  '客户',
#  '分配',
#  '合理化',
#  '考虑',
#  '广告行业',
#  '客户',
#  '流动性',
#  '针对',
#  '已经',
#  '合作',
#  '客户',
#  '制定',
#  '客户',
#  '淘汰',
#  '要求',
#  '标准',
#  '确保',
#  '运力',
#  '得到',
#  '最大',
#  '使用',
#  '减少',
#  '销售',
#  '运营',
#  '跨部门',
#  '冲突',
#  'n7',
#  '客户',
#  '风险',
#  '控制',
#  '制定',
#  '公司',
#  '逾期',
#  '管理',
#  '办法',
#  '根据',
#  '客户',
#  '分类',
#  '风险',
#  '等级',
#  '明确',
#  '销售',
#  '法务',
#  '财务',
#  '应收款',
#  '阶段',
#  '各自',
#  '职责',
#  '主要',
#  '责任',
#  '确保',
#  '逾期',
#  '风险',
#  '得以',
#  '控制',
#  'n4',
#  '法务',
#  '管理',
#  'n1',
#  '合同',
#  '管理',
#  '结合',
#  '业务',
#  '情况',
#  '制定',
#  '公司',
#  '业务',
#  '合作',
#  '合同',
#  '流程',
#  '模板',
#  '审核',
#  '要点',
#  '审核',
#  '节点',
#  '预警',
#  '机制',
#  'n2',
#  '起诉',
#  '管理',
#  '针对',
#  '不同',
#  '类别',
#  '逾期',
#  '员工',
#  '违规',
#  '客户',
#  '应收',
#  '应诉',
#  '进行',
#  '评估',
#  '制定',
#  '相关',
#  '规则',
#  '最大化',
#  '保证',
#  '公司',
#  '利益',
#  'n3',
#  '外部',
#  '律所',
#  '制定',
#  '相关',
#  '律所',
#  '引进',
#  '标准',
#  '价格',
#  '管理',
#  '举证责任',
#  '进行',
#  '规范',
#  '确保',
#  '相关',
#  '案子',
#  '顺利进行',
#  'n5',
#  '销售',
#  '支持',
#  'n1',
#  '拆分',
#  '销售',
#  '职能',
#  '销售',
#  '岗位',
#  '进行',
#  '关键',
#  '内容',
#  '拆分',
#  '销售',
#  '聚焦',
#  '客户',
#  '开发',
#  '回款',
#  '关系',
#  '维护',
#  '消耗',
#  '提升',
#  '上面',
#  'n2',
#  '组建',
#  '部门',
#  '全面',
#  '对非',
#  '销售',
#  '工作',
#  '进行',
#  '支撑',
#  '结算',
#  '充值',
#  '开户',
#  '邮件',
#  '处理',
#  'n3',
#  '明确',
#  '职责',
#  '定位',
#  '职能',
#  '职责',
#  '部门',
#  '导向',
#  '培养',
#  '独挡',
#  '一面',
#  '销售',
#  '支持',
#  '负责人',
#  '工作',
#  '业绩',
#  'n1',
#  '协助',
#  'ceo',
#  '完成',
#  '公司',
#  '薪酬',
#  '改革',
#  '特别',
#  '一线',
#  '销售',
#  '运营',
#  '创意',
#  '岗位',
#  '整个',
#  '公司',
#  '所有',
#  '员工',
#  '进行',
#  '定级',
#  '定岗',
#  '推动',
#  '公司',
#  '全面',
#  '导入',
#  'kpi',
#  '管理',
#  'n2',
#  '明确',
#  '公司',
#  '使命',
#  '愿景',
#  '目标',
#  '具体',
#  '工作',
#  '事业部',
#  '一起',
#  '推进',
#  '确保',
#  '企业',
#  '文化',
#  '具体',
#  '工作',
#  '落实',
#  '一起',
#  'n3',
#  '客户',
#  '系统化',
#  '管理',
#  '拉通',
#  '前端',
#  '确保',
#  '客户',
#  '引入',
#  '上线',
#  '更为',
#  '高效',
#  'n4',
#  '成立',
#  '销售',
#  '支持',
#  '运力',
#  '调度室',
#  '客户部',
#  '更好',
#  '支持',
#  '公司',
#  '相关',
#  '业务',
#  '增长',
#  '120%',
#  'enddate',
#  'id',
#  '2c9207157dbedf8d017dc28fbc5d3366',
#  'jobtitle',
#  '副总裁',
#  '副总经理',
#  'startdate',
#  'companyname',
#  '深圳市',
#  '蜂联',
#  '科技',
#  '有限公司',
#  '奇虎',
#  'description',
#  '工作',
#  '职责',
#  'n1',
#  '策略',
#  '制定',
#  'n1',
#  '结合',
#  '公司',
#  '年度',
#  '发展',
#  '战略',
#  '制定',
#  '电商',
#  '部门',
#  '相关',
#  '战略',
#  '战略',
#  '进行',
#  '拆解',
#  '保证',
#  '公司',
#  '战略',
#  '延续',
#  '部门',
#  '战略',
#  '执行',
#  'n2',
#  '结合',
#  '市场',
#  '公司',
#  '目标',
#  '制定',
#  '公司',
#  '销售',
#  '模型',
#  '以及',
#  '盈利',
#  '模型',
#  '虽然',
#  '几年',
#  '变化',
#  '比较',
#  '基本上',
#  '围绕',
#  '利润',
#  '销量',
#  '平衡',
#  '发展',
#  'n2',
#  '渠道',
#  '管理',
#  'n1',
#  '基于',
#  '行业',
#  '竞争',
#  '充分',
#  '理解',
#  '分析',
#  '制定',
#  '修正',
#  '最近',
#  '渠道',
#  '策略',
#  'n2',
#  '根据',
#  '公司',
#  '年度',
#  '销售额',
#  '重点',
#  '单品',
#  '销量',
#  '目标',
#  '拆分',
#  '各个',
#  '渠道',
#  '销售',
#  '任务',
#  '结合',
#  '各个',
#  '渠道',
#  '差异性',
#  '实时',
#  '一些',
#  '调整',
#  'n3',
#  '根据',
#  '产品',
#  '渠道',
#  '用户',
#  '特点',
#  '布局',
#  '电商',
#  '渠道',
#  '做到',
#  '优势',
#  '渠道',
#  '发掘',
#  '重点',
#  '渠道',
#  '提升',
#  'n4',
#  '渠道',
#  '发展',
#  '以及',
#  '渠道',
#  '布局',
#  '角度',
#  '制定',
#  '渠道',
#  '管理',
#  '制定',
#  '考核',
#  '考核',
#  '激励',
#  '提升',
#  '发展',
#  '重点',
#  '渠道',
#  'n5',
#  '改变',
#  '单一',
#  '奖励制度',
#  '渠道',
#  '进行',
#  '电商',
#  '产品',
#  '营销',
#  '培训',
#  '授之以',
#  '不如',
#  '授之以',
#  '产品',
#  '管理',
#  'n1',
#  '结合',
#  '公司',
#  '产品',
#  '路线图',
#  '建议',
#  '调整',
#  '电商',
#  '部门',
#  '产品',
#  '规划',
#  '保证',
#  '产品',
#  '接近',
#  '市场',
#  '符合',
#  '公司',
#  '需求',
#  'n2',
#  '产品',
#  '立项',
#  '阶段',
#  '利用',
#  '电商',
#  '数据',
#  '准确性',
#  '多样性',
#  '产品',
#  '定义',
#  '提供',
#  '用户',
#  '需求',
#  '分析',
#  'n3',
#  '新建',
#  '优化',
#  '产品',
#  '上市',
#  '流程',
#  '采取',
#  '宣传',
#  '试售',
#  '收集',
#  '分析',
#  '宣传',
#  '上市',
#  '推广',
#  '组合',
#  '手段',
#  '确保',
#  '新品',
#  '上市',
#  '成功',
#  'n4',
#  '产品',
#  '进入',
#  '售卖',
#  '阶段',
#  '重新',
#  '定义',
#  '产品',
#  '买点',
#  '定期',
#  '优化',
#  '调整',
#  '产品',
#  '买点',
#  '确保',
#  '贴近',
#  '市场需求',
#  'n5',
#  '定价',
#  '管理',
#  '根据',
#  '市场竞争',
#  '情况',
#  '以及',
#  '公司',
#  '成本',
#  '毛利',
#  '要求',
#  '产品',
#  '进行',
#  '定价',
#  '根据',
#  '产品',
#  '迭代',
#  '生命周期',
#  '价格',
#  '进行',
#  '调整',
#  '营销策划',
#  'n1',
#  '结合',
#  '公司',
#  '市场',
#  '品牌',
#  '部门',
#  '以及',
#  '电商',
#  '部门',
#  '特点',
#  '制定',
#  '年度',
#  '部门',
#  '营销',
#  '策略',
#  'n2',
#  '制定',
#  '部门',
#  '年度',
#  '营销',
#  '投入',
#  '预算',
#  '执行',
#  '计划',
#  '确保',
#  '投入产出',
#  '最大化',
#  'n3',
#  '建立',
#  '部门',
#  '评审',
#  '机制',
#  '讨论',
#  '机制',
#  '营销',
#  '相关',
#  '进行',
#  '充分',
#  '讨论',
#  '最终',
#  '保证',
#  '风险',
#  '降到',
#  '最低',
#  'n4',
#  '开发新',
#  '宣传',
#  '推广',
#  ...]

# %%
a = [1,2,3]
b = ['hi', 'hello', 'world']
for i,j in zip(a,b):
    print(i,j)
# Out:
# 1 hi
# 2 hello
# 3 world
